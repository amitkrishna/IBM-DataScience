# %%
album_rate = [10.0,8.5,9.5,7.0,8.9,9.5]

# %%
L = len(album_rate)

# %%
print(L)
# Out:
# 6

# %%
sum(album_rate)
# Out:
# 53.4

# %%
sort(album_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-15dfa54698d7> in <module>
# ----> 1 sort(album_rate)
#
# NameError: name 'sort' is not defined

# %%
album_rate.sort()

# %%
album_rate
# Out:
# [7.0, 8.5, 8.9, 9.5, 9.5, 10.0]

# %%
a = 10

# %%
def add1(a):
    b=a+1
    return b
add1(10)
# Out:
# 11

# %%
c = add1(5)

# %%
c
# Out:
# 6
